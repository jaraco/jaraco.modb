# %% [markdown]
# Start out by establishing a connection to a MongoDB instance.

# %%
import pymongo
conn = pymongo.MongoClient()
db = conn.test
coll = db.objects
coll.drop()

# %% [markdown]
# Insert a couple of documents that represent themselves naturally in JSON.

# %%
import datetime
coll.insert_one({'a': datetime.datetime.now(), 'b': 1.0})
coll.insert_one({'items': [1, 2, 3, 'd']})

# %% [markdown]
# But what about more complex objects (classes and instances of those classes)?

# %%
class MyObject:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    
    def __repr__(self):
        return '{self.__class__.__name__}({self.x}, {self.y})'.format(**vars())

ob1 = MyObject(1, 2)
ob2 = MyObject(0, 5)

# %%
coll.insert_one(ob1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-a5e91fbd96fd> in <module>()
# ----> 1 coll.insert_one(ob1)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pymongo-3.2-py3.5-macosx-10.6-intel.egg/pymongo/collection.py in insert_one(self, document, bypass_document_validation)
#     617         .. versionadded:: 3.0
#     618         """
# --> 619         common.validate_is_document_type("document", document)
#     620         if not (isinstance(document, RawBSONDocument) or "_id" in document):
#     621             document["_id"] = ObjectId()
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pymongo-3.2-py3.5-macosx-10.6-intel.egg/pymongo/common.py in validate_is_document_type(option, value)
#     382                         "bson.raw_bson.RawBSONDocument, or "
#     383                         "a type that inherits from "
# --> 384                         "collections.MutableMapping" % (option,))
#     385
#     386
#
# TypeError: document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping

# %%
import jaraco.modb
jaraco.modb.encode(ob1)
# Out:
# {'py/object': '__main__.MyObject', 'x': 1, 'y': 2}

# %% [markdown]
# Because a MyObject instance doesn't have a natural representation in JSON, it's serialized as a dictionary with a special key 'py/object', which signals to the decoder that this is a JSONPickled Python Object. As long as the system doing the decoding implements `__main__.MyObject` with a compatible interface, the object will decode nicely.

# %%
coll.insert_one(jaraco.modb.encode(ob1))
coll.insert_one(jaraco.modb.encode(ob2))

# %% [markdown]
# Now the two objects should be persisted to the database. Query them to see how they appear.

# %%
list(coll.find())
# Out:
# [{'_id': ObjectId('56c9f5ff10334e93a39158b1'),
#   'a': datetime.datetime(2016, 2, 21, 13, 38, 7, 359000),
#   'b': 1.0},
#  {'_id': ObjectId('56c9f5ff10334e93a39158b2'), 'items': [1, 2, 3, 'd']},
#  {'_id': ObjectId('56c9f61410334e93a39158b3'),
#   'py/object': '__main__.MyObject',
#   'x': 1,
#   'y': 2},
#  {'_id': ObjectId('56c9f61410334e93a39158b4'),
#   'py/object': '__main__.MyObject',
#   'x': 0,
#   'y': 5}]

# %%
next(map(jaraco.modb.decode, coll.find({'x': 0})))
# Out:
# MyObject(0, 5)

# %% [markdown]
# But what about more complex objects? Consider ob3 whose x attribute is another MyObject.

# %%
ob3 = MyObject(ob2, 2)
ob3
# Out:
# MyObject(MyObject(0, 5), 2)

# %%
coll.insert_one(jaraco.modb.encode(ob3))

# %% [markdown]
# Because MongoDB's document query engine allows reaching deep into the documents, one can even query based on child object's attributes.

# %%
# Find all objects whose x attribute has a y attribute with a value of 5
query = {'x.y': 5}
next(map(jaraco.modb.decode, coll.find(query)))
# Out:
# MyObject(MyObject(0, 5), 2)

# %% [markdown]
# Where are the limitations? What about integer keys?

# %%
coll.insert_one({1: 3})
# Out:
# ---------------------------------------------------------------------------
# InvalidDocument                           Traceback (most recent call last)
# <ipython-input-12-5d51c33613b8> in <module>()
# ----> 1 coll.insert_one({1: 3})
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pymongo-3.2-py3.5-macosx-10.6-intel.egg/pymongo/collection.py in insert_one(self, document, bypass_document_validation)
#     623             return InsertOneResult(
#     624                 self._insert(sock_info, document,
# --> 625                              bypass_doc_val=bypass_document_validation),
#     626                 self.write_concern.acknowledged)
#     627
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pymongo-3.2-py3.5-macosx-10.6-intel.egg/pymongo/collection.py in _insert(self, sock_info, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val)
#     528             return self._insert_one(
#     529                 sock_info, docs, ordered,
# --> 530                 check_keys, manipulate, write_concern, op_id, bypass_doc_val)
#     531
#     532         ids = []
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pymongo-3.2-py3.5-macosx-10.6-intel.egg/pymongo/collection.py in _insert_one(self, sock_info, doc, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val)
#     510                                        command,
#     511                                        codec_options=self.codec_options,
# --> 512                                        check_keys=check_keys)
#     513             _check_write_command_response([(0, result)])
#     514         else:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pymongo-3.2-py3.5-macosx-10.6-intel.egg/pymongo/pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern)
#     214         # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     215         except BaseException as error:
# --> 216             self._raise_connection_failure(error)
#     217
#     218     def send_message(self, message, max_doc_size):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pymongo-3.2-py3.5-macosx-10.6-intel.egg/pymongo/pool.py in _raise_connection_failure(self, error)
#     341             _raise_connection_failure(self.address, error)
#     342         else:
# --> 343             raise error
#     344
#     345     def __eq__(self, other):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pymongo-3.2-py3.5-macosx-10.6-intel.egg/pymongo/pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern)
#     209                            check, allowable_errors, self.address,
#     210                            check_keys, self.listeners, self.max_bson_size,
# --> 211                            read_concern)
#     212         except OperationFailure:
#     213             raise
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pymongo-3.2-py3.5-macosx-10.6-intel.egg/pymongo/network.py in command(sock, dbname, spec, slave_ok, is_mongos, read_preference, codec_options, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern)
#      76
#      77     request_id, msg, size = message.query(flags, ns, 0, -1, spec,
# ---> 78                                           None, codec_options, check_keys)
#      79
#      80     if (max_bson_size is not None
#
# InvalidDocument: documents must have only string keys, key was 1

# %%
res = coll.insert_one(jaraco.modb.encode({1: 3}))

# %%
coll.find_one({'_id': res.inserted_id})
# Out:
# {'1': 3, '_id': ObjectId('56c9f63910334e93a39158b8')}

# %% [markdown]
# You might note that the integer 1 is now represented as a string '1'. This limitation is an unfortunate side-effect of relying on JSON as a serialization layer.
